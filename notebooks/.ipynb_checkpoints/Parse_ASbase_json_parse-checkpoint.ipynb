# %%
import json
from pprint import pprint

# %%
json_data=open('../data/ASbaseResponse.json')

pprint(json_data)
# Out:
# <open file '../data/ASbaseResponse.json', mode 'r' at 0x103696f60>

# %%
data = json.load(json_data)
pprint(data)
json_data.close()
# Out:
# {u'@type': u'http://activitystrea.ms/2.0/Collection',
#  u'items': [{u'actor': {u'displayName': u'Unknown',
#                         u'objectType': u'person'},
#              u'id': u'http://128.32.78.37:8080/activities/3ebf9c6103f841e4ade15726d596ad7f',
#              u'object': {u'descriptor_tags': [u'chair', u'rolling'],
#                          u'displayName': u'Chair at 202 South Hall, UC Berkeley',
#                          u'id': u'http://example.org/berkeley/southhall/202/chair/1',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': 100.05,
#                                        u'latitude': 34.34,
#                                        u'longitude': -127.23}},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'verb': u'leave'},
#             {u'actor': {u'displayName': u'Unknown',
#                         u'objectType': u'person'},
#              u'id': u'http://128.32.78.37:8080/activities/094f38e05aa9408b97dd01c4edd97be2',
#              u'object': {u'descriptor_tags': [u'chair', u'rolling'],
#                          u'displayName': u'Chair at 202 South Hall, UC Berkeley',
#                          u'id': u'http://example.org/berkeley/southhall/202/chair/1',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': 100.05,
#                                        u'latitude': 34.34,
#                                        u'longitude': -127.23}},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'verb': u'checkin'},
#             {u'actor': {u'displayName': u'Unknown',
#                         u'objectType': u'person'},
#              u'id': u'http://128.32.78.37:8080/activities/35beaf7ecd394e16ba11cd15e9dbc5ec',
#              u'object': {u'descriptor_tags': [u'chair', u'rolling'],
#                          u'displayName': u'Chair at 202 South Hall, UC Berkeley',
#                          u'id': u'http://example.org/berkeley/southhall/202/chair/1',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': 100.05,
#                                        u'latitude': 34.34,
#                                        u'longitude': -127.23}},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'verb': u'leave'},
#             {u'actor': {u'displayName': u'Unknown',
#                         u'objectType': u'person'},
#              u'id': u'http://128.32.78.37:8080/activities/ebbaa07648994f5fb6f0f3c733818f2e',
#              u'object': {u'descriptor_tags': [u'chair', u'rolling'],
#                          u'displayName': u'Chair at 202 South Hall, UC Berkeley',
#                          u'id': u'http://example.org/berkeley/southhall/202/chair/1',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': 100.05,
#                                        u'latitude': 34.34,
#                                        u'longitude': -127.23}},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'verb': u'leave'},
#             {u'actor': {u'displayName': u'Unknown',
#                         u'objectType': u'person'},
#              u'id': u'http://128.32.78.37:8080/activities/8027efdda03244fa85079f9f4c02ebb8',
#              u'object': {u'descriptor_tags': [u'chair', u'rolling'],
#                          u'displayName': u'Chair at 202 South Hall, UC Berkeley',
#                          u'id': u'http://example.org/berkeley/southhall/202/chair/1',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': 100.05,
#                                        u'latitude': 34.34,
#                                        u'longitude': -127.23}},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'verb': u'checkin'},
#             {u'actor': {u'displayName': u'Unknown',
#                         u'objectType': u'person'},
#              u'id': u'http://128.32.78.37:8080/activities/8f66aac194374938beaf1bf1dca284be',
#              u'object': {u'descriptor_tags': [u'chair', u'rolling'],
#                          u'displayName': u'Chair at 202 South Hall, UC Berkeley',
#                          u'id': u'http://example.org/berkeley/southhall/202/chair/1',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': 100.05,
#                                        u'latitude': 34.34,
#                                        u'longitude': -127.23}},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'verb': u'leave'},
#             {u'actor': {u'displayName': u'Unknown',
#                         u'objectType': u'person'},
#              u'id': u'http://128.32.78.37:8080/activities/9f13612b5b6948a0b6b6171d7f551752',
#              u'object': {u'descriptor_tags': [u'chair', u'rolling'],
#                          u'displayName': u'Chair at 202 South Hall, UC Berkeley',
#                          u'id': u'http://example.org/berkeley/southhall/202/chair/1',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': 100.05,
#                                        u'latitude': 34.34,
#                                        u'longitude': -127.23}},
#              u'verb': u'leave'},
#             {u'actor': {u'displayName': u'Unknown',
#                         u'objectType': u'person'},
#              u'id': u'http://128.32.78.37:8080/activities/96203ca2f02040e1b8babcfa9ca0b0c9',
#              u'object': {u'descriptor_tags': [u'chair', u'rolling'],
#                          u'displayName': u'Chair at 202 South Hall, UC Berkeley',
#                          u'id': u'http://example.org/berkeley/southhall/202/chair/1',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': 100.05,
#                                        u'latitude': 34.34,
#                                        u'longitude': -127.23}},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'verb': u'leave'},
#             {u'actor': {u'displayName': u'Unknown',
#                         u'objectType': u'person'},
#              u'id': u'http://128.32.78.37:8080/activities/72c24d2503424730b41d04b38b038099',
#              u'object': {u'descriptor_tags': [u'chair', u'rolling'],
#                          u'displayName': u'Chair at 202 South Hall, UC Berkeley',
#                          u'id': u'http://example.org/berkeley/southhall/202/chair/1',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': 100.05,
#                                        u'latitude': 34.34,
#                                        u'longitude': -127.23}},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'verb': u'checkin'},
#             {u'actor': {u'displayName': u'Unknown',
#                         u'objectType': u'person'},
#              u'id': u'http://128.32.78.37:8080/activities/7725d5a6ba3e4167b04cafaca6a16352',
#              u'object': {u'descriptor_tags': [u'chair', u'rolling'],
#                          u'displayName': u'Chair at 202 South Hall, UC Berkeley',
#                          u'id': u'http://example.org/berkeley/southhall/202/chair/1',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': 100.05,
#                                        u'latitude': 34.34,
#                                        u'longitude': -127.23}},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'verb': u'leave'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/11f4986ab1b64cae88490cf823064d2a',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/0dcd84008fbc490aaa276bf34598c992',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/e45c46e5309a4d42a691a1e1658414e1',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/d8eafe2c1b1d44ffbfb557659967a09b',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/45c43c4486a84d58b0f1a109cab57a9c',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/9d25d7e36c67466d9088bc35bc0af121',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/ea0a0c287adb4e99bff3e12cf9b11159',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/1d14898744ef4bb387e43b61e2de86fe',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/e6343e7b30904137b402c43198a4781e',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/15676a9c5ce64d379f1c5d7f7cfeeaf3',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/dd745679049e4a5c86d73db8e0499401',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/07e7a43996f24ca4a453a2933b5f7afc',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/f132b0c406734572881a5d74d38904de',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/f783d5b8539c4347bea8b6ccd5e12c3a',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/530de41293f14dfeb9d41547c5422018',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/9a5b1b2eb1294a61943fbaab89db48fa',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/388246b22e2d47eda1fcf6d2d85ce04d',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/9727af4808984d50b7de68b2249beafc',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/a01a1908b68d44649aa8a825730fb20a',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/857c391900d2449496b78ee922aea2ca',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Martin Smith',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'id': u'http://128.32.78.37:8080/activities/6a9f959b02654bc199389cac2b3a485c',
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'actor': {u'displayName': u'Jane Smith',
#                         u'id': u'http://example.org/janesmith',
#                         u'objectType': u'person'},
#              u'id': u'http://128.32.78.37:8080/activities/f972911c21b34d2494c202d1e7fe60b7',
#              u'object': {u'dataFields': [u'time',
#                                          u'HR',
#                                          u'steps',
#                                          u'GSR',
#                                          u'stemp',
#                                          u'atemp'],
#                          u'objectType': u'exerciseRecord',
#                          u'url': u'http://russet.ischool.berkeley.edu:8081/tim_testdata/basisdata_patient5_all.csv'},
#              u'published': u'2015-01-06T15:04:55.000Z',
#              u'status': u'completed',
#              u'verb': u'add'},
#             {u'actor': {u'displayName': u'John Doe',
#                         u'id': u'http://example.org/johndoe',
#                         u'objectType': u'person'},
#              u'endTime': u'2014-06-17T18:52:00.000Z',
#              u'id': u'http://128.32.78.37:8080/activities/54c8ac3cb1f642f29583e93e06ca3436',
#              u'object': {u'dataFields': [u'time',
#                                          u'HR',
#                                          u'steps',
#                                          u'GSR',
#                                          u'stemp',
#                                          u'atemp'],
#                          u'objectType': u'exerciseRecord',
#                          u'url': u'http://russet.ischool.berkeley.edu:8081/tim_testdata/basisdata_patient1_cycling.csv'},
#              u'published': u'2015-01-06T15:04:55.000Z',
#              u'startTime': u'2014-06-17T18:14:00.000Z',
#              u'status': u'completed',
#              u'subVerb': u'http://siemens.com/schemas/activity#Cycling',
#              u'verb': u'add'},
#             {u'actor': {u'displayName': u'John Doe',
#                         u'id': u'http://example.org/johndoe',
#                         u'objectType': u'person'},
#              u'id': u'http://128.32.78.37:8080/activities/833f539520634c6da89fd92484db9ddd',
#              u'object': {u'dataFields': [u'time',
#                                          u'HR',
#                                          u'steps',
#                                          u'GSR',
#                                          u'stemp',
#                                          u'atemp'],
#                          u'objectType': u'exerciseRecord',
#                          u'url': u'http://russet.ischool.berkeley.edu:8081/tim_testdata/basisdata_patient1_all.csv'},
#              u'published': u'2015-01-06T15:04:55.000Z',
#              u'status': u'completed',
#              u'verb': u'add'},
#             {u'actor': {u'displayName': u'Siemens Wind Turbine 11',
#                         u'id': u'http://example.org/windturbine_11',
#                         u'objectType': u'device'},
#              u'endTime': u'2014-06-17T18:52:00.000Z',
#              u'id': u'http://128.32.78.37:8080/activities/24704fcd908545bc90e60c86c983376c',
#              u'object': {u'dataFields': [u'time',
#                                          u'powerOutput',
#                                          u'windSpeed'],
#                          u'objectType': u'exerciseRecord',
#                          u'url': u'http://russet.ischool.berkeley.edu:8081/tim_testdata/data_turbine11_maintenance.csv'},
#              u'published': u'2015-01-06T15:04:55.000Z',
#              u'startTime': u'2014-06-17T18:14:00.000Z',
#              u'status': u'completed',
#              u'subVerb': u'http://siemens.com/schemas/activity#Maintenance',
#              u'verb': u'add'},
#             {u'actor': {u'displayName': u'Siemens Wind Turbine 11',
#                         u'id': u'http://example.org/windturbine_11',
#                         u'objectType': u'device'},
#              u'id': u'http://128.32.78.37:8080/activities/57bdffc1eda24703aae1e66bde0b86f2',
#              u'object': {u'dataFields': [u'time',
#                                          u'powerOutput',
#                                          u'windSpeed'],
#                          u'objectType': u'exerciseRecord',
#                          u'url': u'http://russet.ischool.berkeley.edu:8081/tim_testdata/data_turbine11_all.csv'},
#              u'published': u'2015-01-06T15:04:55.000Z',
#              u'status': u'completed',
#              u'verb': u'add'},
#             {u'UUID': u'cc4fd652ebae4293b047689efabc9155',
#              u'actor': {u'displayName': u'TestSeat',
#                         u'objectType': u'person'},
#              u'descriptor-tags': [u'chair', u'rolling'],
#              u'endTime': u'2015-03-11T00:04:55.000Z',
#              u'object': {u'displayName': u'Chair',
#                          u'id': u'chairID',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': u'100.05',
#                                        u'latitude': u'34.34',
#                                        u'longitude': u'-127.23'}},
#              u'requestID': u'personID',
#              u'startTime': u'2015-03-10T00:04:55.000Z',
#              u'verb': u'request'},
#             {u'UUID': u'cca19ccedc854b7f851aa0d208466cad',
#              u'actor': {u'displayName': u'TestSeat',
#                         u'objectType': u'person'},
#              u'descriptor-tags': [u'chair', u'rolling'],
#              u'endTime': u'2015-03-11T00:04:55.000Z',
#              u'object': {u'displayName': u'Chair',
#                          u'id': u'chairID',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': u'',
#                                        u'latitude': u'',
#                                        u'longitude': u''}},
#              u'requestID': u'personID',
#              u'startTime': u'2015-03-10T00:04:55.000Z',
#              u'verb': u'request'},
#             {u'UUID': u'8dc297d81bb9484f84c9706a8472c491',
#              u'actor': {u'displayname': u'TestSeat',
#                         u'objectType': u'person'},
#              u'descriptor-tags': [u'chair', u'rolling'],
#              u'endTime': u'2015-03-11T00:04:55.000Z',
#              u'object': {u'displayName': u'Chair',
#                          u'id': u'chairID',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': u'',
#                                        u'latitude': u'',
#                                        u'longitude': u''}},
#              u'requestID': u'personID',
#              u'startTime': u'2015-03-10T00:04:55.000Z',
#              u'verb': u'post'},
#             {u'UUID': u'c88bda3d132448329ab44924c98bb765',
#              u'actor': {u'displayName': u'TestSeat',
#                         u'objectType': u'person'},
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'verb': u'post'},
#             {u'UUID': u'480ef36e0ca64cf0afd76d623d8ef009',
#              u'actor': {u'displayname': u'TestSeat',
#                         u'objectType': u'person'},
#              u'descriptor-tags': [u'chair', u'rolling'],
#              u'endTime': u'2015-03-11T00:04:55.000Z',
#              u'object': {u'displayName': u'Chair',
#                          u'id': u'chairID',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': u'',
#                                        u'latitude': u'',
#                                        u'longitude': u''}},
#              u'requestID': u'personID',
#              u'startTime': u'2015-03-10T00:04:55.000Z',
#              u'verb': u'request'},
#             {u'UUID': u'fb252a7d5abe403890778645eb7d7c34',
#              u'actor': {u'displayname': u'TestSeat',
#                         u'objectType': u'person'},
#              u'descriptor-tags': [u'chair', u'rolling'],
#              u'endTime': u'2015-03-11T00:04:55.000Z',
#              u'object': {u'displayName': u'Chair',
#                          u'id': u'chairID',
#                          u'objectType': u'place'},
#              u'requestID': u'personID',
#              u'startTime': u'2015-03-10T00:04:55.000Z',
#              u'verb': u'request'},
#             {u'UUID': u'bd986f65f8414aba92436028d4472ded',
#              u'actor': {u'displayname': u'TestSeat',
#                         u'objectType': u'person'},
#              u'descriptor-tags': [u'chair', u'rolling'],
#              u'endTime': u'2015-03-11T00:04:55.000Z',
#              u'object': {u'displayName': u'Chair',
#                          u'id': u'chairID',
#                          u'objectType': u'place'},
#              u'requestID': u'personID',
#              u'startTime': u'2015-03-10T00:04:55.000Z',
#              u'verb': u'request'},
#             {u'UUID': u'424f93b098824ee39b3da31ca1a017a7',
#              u'actor': {u'displayname': u'TestSeat',
#                         u'objectType': u'person'},
#              u'endTime': u'2015-03-11T00:04:55.000Z',
#              u'object': {u'displayName': u'Chair',
#                          u'id': u'chairID',
#                          u'objectType': u'place'},
#              u'requestID': u'personID',
#              u'startTime': u'2015-03-10T00:04:55.000Z',
#              u'verb': u'request'},
#             {u'UUID': u'94e56ee87bdd437eb8ccb1bd00042409',
#              u'actor': {u'displayname': u'TestSeat',
#                         u'objectType': u'person'},
#              u'endTime': u'2015-03-11T00:04:55.000Z',
#              u'object': {u'displayName': u'Chair',
#                          u'id': u'chairID',
#                          u'objectType': u'place'},
#              u'startTime': u'2015-03-10T00:04:55.000Z',
#              u'verb': u'request'},
#             {u'UUID': u'5e838029e4304c2c945efe24743be158',
#              u'actor': {u'displayname': u'TestSeat',
#                         u'objectType': u'person'},
#              u'object': {u'displayName': u'',
#                          u'id': u'',
#                          u'objectType': u'place',
#                          u'position': {u'altitude': u'',
#                                        u'latitude': u'',
#                                        u'longitude': u''}},
#              u'verb': u'request'},
#             {u'UUID': u'b1de74527b6448649645ffd1ddc045ef',
#              u'actor': {u'displayName': u'TestSeat',
#                         u'id': u'tag:example.org,2011:martin',
#                         u'objectType': u'person',
#                         u'url': u'http://example.org/martin'},
#              u'object': {u'id': u'tag:example.org,2011:abc123/xyz',
#                          u'url': u'http://example.org/blog/2011/02/entry'},
#              u'published': u'2011-02-10T15:04:55.000Z',
#              u'target': {u'displayName': u"Martin's Blog",
#                          u'id': u'tag:example.org,2011:abc123',
#                          u'objectType': u'blog',
#                          u'url': u'http://example.org/blog/'},
#              u'verb': u'post'},
#             {u'UUID': u'408f8faed3a14e8db2acf3b89dec35ce',
#              u'actor': {u'displayName': u'TestPatient',
#                         u'id': u'http://example.org/TestPatient',
#                         u'objectType': u'person'},
#              u'object': {u'dataFields': [u'time',
#                                          u'HR',
#                                          u'steps',
#                                          u'GSR',
#                                          u'stemp',
#                                          u'atemp'],
#                          u'objectType': u'exerciseRecord',
#                          u'url': u'http://russet.ischool.berkeley.edu:8081/tim_testdata/basisdata_patient1_all.csv'},
#              u'published': u'2015-01-06T15:04:55.000Z',
#              u'status': u'completed',
#              u'uuid': u'http://example.org/activities/TestPatient_add_1234',
#              u'verb': u'add'},
#             {u'UUID': u'3687198d00da48b3a420b6b323781029',
#              u'actor': {u'displayName': u'TestPatient',
#                         u'id': u'http://example.org/TestPatient',
#                         u'objectType': u'person'},
#              u'endTime': u'2014-06-17T18:52:00.000Z',
#              u'object': {u'dataFields': [u'time',
#                                          u'HR',
#                                          u'steps',
#                                          u'GSR',
#                                          u'stemp',
#                                          u'atemp'],
#                          u'objectType': u'exerciseRecord',
#                          u'url': u'http://russet.ischool.berkeley.edu:8081/tim_testdata/basisdata_patient1_cycling.csv'},
#              u'published': u'2015-01-06T15:04:55.000Z',
#              u'startTime': u'2014-06-17T18:14:00.000Z',
#              u'status': u'completed',
#              u'subVerb': u'http://siemens.com/schemas/activity#Cycling',
#              u'uuid': u'http://example.org/activities/TestPatient_add_cycling_4321',
#              u'verb': u'add'},
#             {u'UUID': u'3a04936ad8a34dc39e078cc993cc5ba2',
#              u'actor': {u'displayName': u'TestPatient 5',
#                         u'id': u'http://example.org/TestPatient5',
#                         u'objectType': u'person'},
#              u'object': {u'dataFields': [u'time',
#                                          u'HR',
#                                          u'steps',
#                                          u'GSR',
#                                          u'stemp',
#                                          u'atemp'],
#                          u'objectType': u'exerciseRecord',
#                          u'url': u'http://russet.ischool.berkeley.edu:8081/tim_testdata/basisdata_patient5_all.csv'},
#              u'published': u'2015-01-06T15:04:55.000Z',
#              u'status': u'completed',
#              u'uuid': u'http://example.org/activities/TestPatient5_add_1332',
#              u'verb': u'add'}],
#  u'totalItems': 50}

# %%
data['items'][0]['actor']
# Out:
# {u'displayName': u'Unknown', u'objectType': u'person'}

# %%
len(data['items'])
# Out:
# 50

# %%
for ix, activity in enumerate(data['items']):
    try:
        if activity['actor']['displayName'] == 'TestSeat':
            print 'Actor: ', activity['actor']
            print 'All: ', activity, '\n\n'
    except Exception as e:
        print 'Error: ', e, '\n\n'
# Out:
# Actor:  {u'displayName': u'TestSeat', u'objectType': u'person'}
# All:  {u'UUID': u'cc4fd652ebae4293b047689efabc9155', u'object': {u'position': {u'latitude': u'34.34', u'altitude': u'100.05', u'longitude': u'-127.23'}, u'displayName': u'Chair', u'id': u'chairID', u'objectType': u'place'}, u'actor': {u'displayName': u'TestSeat', u'objectType': u'person'}, u'descriptor-tags': [u'chair', u'rolling'], u'verb': u'request', u'requestID': u'personID', u'startTime': u'2015-03-10T00:04:55.000Z', u'endTime': u'2015-03-11T00:04:55.000Z'}
#
#
# Actor:  {u'displayName': u'TestSeat', u'objectType': u'person'}
# All:  {u'UUID': u'cca19ccedc854b7f851aa0d208466cad', u'object': {u'position': {u'latitude': u'', u'altitude': u'', u'longitude': u''}, u'displayName': u'Chair', u'id': u'chairID', u'objectType': u'place'}, u'actor': {u'displayName': u'TestSeat', u'objectType': u'person'}, u'descriptor-tags': [u'chair', u'rolling'], u'verb': u'request', u'requestID': u'personID', u'startTime': u'2015-03-10T00:04:55.000Z', u'endTime': u'2015-03-11T00:04:55.000Z'}
#
#
# Error:  'displayName'
#
#
# Actor:  {u'displayName': u'TestSeat', u'objectType': u'person'}
# All:  {u'verb': u'post', u'UUID': u'c88bda3d132448329ab44924c98bb765', u'actor': {u'displayName': u'TestSeat', u'objectType': u'person'}, u'object': {u'url': u'http://example.org/blog/2011/02/entry', u'id': u'tag:example.org,2011:abc123/xyz'}}
#
#
# Error:  'displayName'
#
#
# Error:  'displayName'
#
#
# Error:  'displayName'
#
#
# Error:  'displayName'
#
#
# Error:  'displayName'
#
#
# Error:  'displayName'
#
#
# Actor:  {u'url': u'http://example.org/martin', u'displayName': u'TestSeat', u'id': u'tag:example.org,2011:martin', u'objectType': u'person'}
# All:  {u'target': {u'url': u'http://example.org/blog/', u'displayName': u"Martin's Blog", u'id': u'tag:example.org,2011:abc123', u'objectType': u'blog'}, u'object': {u'url': u'http://example.org/blog/2011/02/entry', u'id': u'tag:example.org,2011:abc123/xyz'}, u'actor': {u'url': u'http://example.org/martin', u'displayName': u'TestSeat', u'id': u'tag:example.org,2011:martin', u'objectType': u'person'}, u'verb': u'post', u'published': u'2011-02-10T15:04:55.000Z', u'UUID': u'b1de74527b6448649645ffd1ddc045ef'}
